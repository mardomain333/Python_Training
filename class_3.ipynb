# %% [markdown]
# ## Day 3                                                                                 20/02/2026

# %% [markdown]
# ### File Handling

# %%
import os
with open(r'C:\Users\Administrator\Desktop\Day3\demofile.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# hi Goodmorning !

# %%
#writing to a file
import os
os.getenv(r'C:\Users\Administrator')
lst=open(r'Desktop\Day3\newfile.txt','w')
lst.write("This is lst module2 \nThis is 2nd module ")
lst.close()

# %%
#reading from a file 
lst=open(r'Desktop\Day3\newfile.txt','r')
lst.read()
# Out:
# 'This is lst module2 \nThis is 2nd module '

# %%
st="This is lst module2 \nThis is 2nd module "
st[5:11]
# Out:
# 'is lst'

# %%
lst=open('newfile.txt','r')
print(lst.read(8))  #pointer will start read upto t
print(lst.tell())  #it will tell your pointer position
# Out:
# this is
# 8

# %%
lst.seek(2)
lst.tell()
# Out:
# 2

# %%
lst=open(r'Desktop\Day3\newfile.txt','r')
lst.readline()  #this will read one line
# Out:
# 'This is lst module2 \n'

# %%
lst.readlines()
# Out:
# ['This is 2nd module ']

# %% [markdown]
# Renaming & Deleting files in Python

# %%
import os
os.getenv(r'C:\Users\Administrator')
os.rename('\Desktop\Day3\newfile.txt','\Desktop\Day3\sample.txt')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10208\3683171616.py:3: SyntaxWarning: invalid escape sequence '\D'
#   os.rename('\Desktop\Day3\newfile.txt','\Desktop\Day3\sample.txt')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10208\3683171616.py:3: SyntaxWarning: invalid escape sequence '\D'
#   os.rename('\Desktop\Day3\newfile.txt','\Desktop\Day3\sample.txt')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10208\3683171616.py:3: SyntaxWarning: invalid escape sequence '\D'
#   os.rename('\Desktop\Day3\newfile.txt','\Desktop\Day3\sample.txt')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10208\3683171616.py:3: SyntaxWarning: invalid escape sequence '\D'
#   os.rename('\Desktop\Day3\newfile.txt','\Desktop\Day3\sample.txt')
# ...

# %%
os.remove("newfile.txt")

# %% [markdown]
# ### Python Directory & File management

# %%
import os
os.getcwd() #to get the current directory
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir(r"C:\Users\Administrator\Desktop")

# %%
os.listdir(os.getcwd())
# Out:
# ['Day3',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDB Compass.lnk',
#  'Readme - Shortcut.lnk']

# %% [markdown]
# ### Create new Directory

# %%
os.mkdir('demofolder') 

os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %% [markdown]
# Modules and packages

# %%
import os
os.getenv("USERPROFILE")
# Out:
# 'C:\\Users\\Administrator'

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 12, 50, 18, 18339)

# %%
#importing with renaming
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
#From.. import statement

from datetime import datetime

datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 12, 51, 45, 702612)

# %%
#import all names

from math import *
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ### Python Testing

# %%
#write
